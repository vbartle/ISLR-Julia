# %%
import Pkg
Pkg.add("CSV")
using CSV
Pkg.add("DataFrames")
using DataFrames
# Out:
#  Resolving package versions...
#   Updating `~/.julia/environments/v1.1/Project.toml`
#  [no changes]
#   Updating `~/.julia/environments/v1.1/Manifest.toml`
#  [no changes]
#  Resolving package versions...
#   Updating `~/.julia/environments/v1.1/Project.toml`
#  [no changes]
#   Updating `~/.julia/environments/v1.1/Manifest.toml`
#  [no changes]

# %%
df = CSV.File("Wage.csv") |> DataFrame!
# Out:
# 3000×13 DataFrame. Omitted printing of 7 columns
# │ Row  │ Column1 │ year  │ age   │ sex     │ maritl           │ race     │
# │      │ Int64   │ Int64 │ Int64 │ String  │ String           │ String   │
# ├──────┼─────────┼───────┼───────┼─────────┼──────────────────┼──────────┤
# │ 1    │ 231655  │ 2006  │ 18    │ 1. Male │ 1. Never Married │ 1. White │
# │ 2    │ 86582   │ 2004  │ 24    │ 1. Male │ 1. Never Married │ 1. White │
# │ 3    │ 161300  │ 2003  │ 45    │ 1. Male │ 2. Married       │ 1. White │
# │ 4    │ 155159  │ 2003  │ 43    │ 1. Male │ 2. Married       │ 3. Asian │
# │ 5    │ 11443   │ 2005  │ 50    │ 1. Male │ 4. Divorced      │ 1. White │
# │ 6    │ 376662  │ 2008  │ 54    │ 1. Male │ 2. Married       │ 1. White │
# │ 7    │ 450601  │ 2009  │ 44    │ 1. Male │ 2. Married       │ 4. Other │
# │ 8    │ 377954  │ 2008  │ 30    │ 1. Male │ 1. Never Married │ 3. Asian │
# │ 9    │ 228963  │ 2006  │ 41    │ 1. Male │ 1. Never Married │ 2. Black │
# ...

# %%
using Plots
# Out:
# ┌ Info: Recompiling stale cache file /Users/vb/.julia/compiled/v1.1/Plots/ld3vC.ji for Plots [91a5bcdd-55d7-5caf-9e0b-520d859cae80]
# └ @ Base loading.jl:1184

# %%
names(df)
# Out:
# 13-element Array{Symbol,1}:
#  :Column1
#  :year
#  :age
#  :sex
#  :maritl
#  :race
#  :education
#  :region
#  :jobclass
#  :health
#  :health_ins
#  :logwage
#  :wage

# %%
scatter(df.age,df.wage)

# %%
Pkg.add("StatsPlots")
using StatsPlots
# Out:
#  Resolving package versions...
#  Installed KernelDensity ────────── v0.5.1
#  Installed AxisAlgorithms ───────── v1.0.0
#  Installed StatsPlots ───────────── v0.10.2
#  Installed NLSolversBase ────────── v7.4.1
#  Installed Ratios ───────────────── v0.3.1
#  Installed BinDeps ──────────────── v0.8.10
#  Installed CommonSubexpressions ─── v0.2.0
#  Installed Clustering ───────────── v0.13.3
#  Installed TableTraitsUtils ─────── v1.0.0
#  Installed ArrayInterface ───────── v1.2.1
#  Installed FillArrays ───────────── v0.6.4
#  Installed QuadGK ───────────────── v2.0.3
#  Installed PDMats ───────────────── v0.9.9
#  Installed Distributions ────────── v0.21.1
#  Installed PositiveFactorizations ─ v0.2.2
#  Installed IterableTables ───────── v0.11.0
#  Installed AbstractFFTs ─────────── v0.4.1
#  Installed Calculus ─────────────── v0.5.0
#  Installed Rmath ────────────────── v0.5.0
#  Installed Interpolations ───────── v0.12.2
#  Installed NearestNeighbors ─────── v0.4.3
# ...

# %%
boxplot(df.year,df.wage)

# %%
boxplot(df.education,df.wage)

# %%
dfS = CSV.File("Data/Smarket.csv") |> DataFrame!
# Out:
# 1250×10 DataFrame. Omitted printing of 3 columns
# │ Row  │ Column1 │ Year  │ Lag1    │ Lag2    │ Lag3    │ Lag4    │ Lag5    │
# │      │ Int64   │ Int64 │ Float64 │ Float64 │ Float64 │ Float64 │ Float64 │
# ├──────┼─────────┼───────┼─────────┼─────────┼─────────┼─────────┼─────────┤
# │ 1    │ 1       │ 2001  │ 0.381   │ -0.192  │ -2.624  │ -1.055  │ 5.01    │
# │ 2    │ 2       │ 2001  │ 0.959   │ 0.381   │ -0.192  │ -2.624  │ -1.055  │
# │ 3    │ 3       │ 2001  │ 1.032   │ 0.959   │ 0.381   │ -0.192  │ -2.624  │
# │ 4    │ 4       │ 2001  │ -0.623  │ 1.032   │ 0.959   │ 0.381   │ -0.192  │
# │ 5    │ 5       │ 2001  │ 0.614   │ -0.623  │ 1.032   │ 0.959   │ 0.381   │
# │ 6    │ 6       │ 2001  │ 0.213   │ 0.614   │ -0.623  │ 1.032   │ 0.959   │
# │ 7    │ 7       │ 2001  │ 1.392   │ 0.213   │ 0.614   │ -0.623  │ 1.032   │
# │ 8    │ 8       │ 2001  │ -0.403  │ 1.392   │ 0.213   │ 0.614   │ -0.623  │
# │ 9    │ 9       │ 2001  │ 0.027   │ -0.403  │ 1.392   │ 0.213   │ 0.614   │
# ...

# %%
boxplot(dfS.Direction, dfS.Lag1)

# %%
boxplot(dfS.Direction, dfS.Lag2)

# %%
boxplot(dfS.Direction, dfS.Lag3)
